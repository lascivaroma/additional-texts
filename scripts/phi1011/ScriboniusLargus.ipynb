# %%
import lxml.etree as ET
from tqdm import tqdm

import sys
print(sys.version)
# Out:
# 3.6.9 (default, Oct  8 2020, 12:12:24)
# [GCC 8.4.0]

# %%
xml = ET.parse("cua_scriboniilarg00scri_djvu.xml")

# %%
from collections import namedtuple
from statistics import median, stdev
from typing import List

Bbox = namedtuple("Bbox", ["left", "bottom", "right", "top"])
Word = namedtuple("Word", ["text", "bbox"])


class Line:
    def __init__(self, no, p_no):
        self.words = []
        self.id = no
        self.paragraph_id = p_no
        
    def add_word(self, element):
        self.words.append(
            Word(
                element.text.strip(),
                Bbox(*[
                    float(value)
                    for value in element.attrib["coords"].split(",")[:4]
                ])
            )
        )
    
    @property
    def bottom(self) -> float:
        return median([w.bbox.bottom for w in self.words])
    
    @property
    def top(self) -> float:
        return median([w.bbox.top for w in self.words])
    
    @property
    def left(self) -> float:
        return min([w.bbox.left for w in self.words])
    
    @property
    def right(self) -> float:
        return max([w.bbox.right for w in self.words])

    @property
    def coords(self) -> List[float]:
        return [self.left, self.bottom, self.right, self.top]
    
    @property
    def text(self):
        return " ".join([w.text for w in self.words])
    
    def __repr__(self):
        return f"<Line>{self.text}</Line>"
    
class Page:
    def __init__(self, no, uri):
        self.lines = []
        self.uri = uri
        self.id = no
        self._distances = None

    def add_line(self, line):
        self.lines.append(line)
    
    @property
    def distances(self) -> List[float]:
        if not self._distances:
            dists = []
            last_line = None
            
            for line in self.lines:
                if last_line == None:
                    last_line = line.bottom
                    continue
                dists.append(line.bottom - last_line)
                last_line = line.bottom
            
            self._distances = dists
        return self._distances
    
    @property
    def median(self) -> float:
        return median(self._distances)

    def __len__(self):
        return len(self.lines)
    
    @property
    def stdev(self):
        return stdev(self.distances)
    
    def is_break(self, distance) -> bool:
        """ Check if the distance is higher than the stdev """
        return distance > (self.stdev + self.median)
    
    def iter_lines(self):
        for line, dist in zip(self.lines, [None] + self.distances):
            yield (
                dist is None or self.is_break(dist),  # does it break ?
                line,
                dist
            )
            
    @property
    def nb_blocks(self):
        if len(self) <= 2:
            return len(self)
        return sum([
            int(is_breaking)
            for is_breaking, _, _ in self.iter_lines()
        ])

    def iter_blocks(self):
        block = []
        for is_breaking, line, _ in self.iter_lines():
            if is_breaking and block:
                yield block
                block = []
            block.append(line)
        if block:
            yield block
    
pages = []
for page_no, page_element in enumerate(xml.xpath("/DjVuXML/BODY/OBJECT")):
    uri = f"https://archive.org/details/cuascriboniilarg00scri/page/n{page_no}/mode/1up"
    page = Page(page_no, uri=uri)
    line_no = 1
    for p_no, paragraph in enumerate(page_element.xpath(".//PARAGRAPH")):
        for line_element in paragraph.xpath(".//LINE"):
            # print(" ".join([word.text for word in line.xpath(".//WORD")])) 
            words = line_element.xpath(".//WORD")
            if len(words):
                line = Line(line_no, p_no)
                for word in words:
                    line.add_word(word)
                page.add_line(line)
                line_no += 1
    
    nb_breaks = page.nb_blocks
    if len(page) > 2 and nb_breaks > 3:
        for line, dist in zip(page.lines, [None] + page.distances):
            print(dist is None or page.is_break(dist), line.text)
    print("\n=================\n")
    pages.append(page)
# Out:
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
# True — VII —
# True reliquisse ingenue fateor; itaque opto ; ut tandem aut
# False Ruellii codex iterum aut si quis alius vetustior et inte-
# False grior aetatem tulit in medium proferatur. Quo facto eam
# False quoque quaestionem profligatum iri spero ; quae me multum
# False diuque torsit deliberantem ; utrum Scribonius hunc librum
# False de conpositionibus medicamentorum an ; quod mihi placuit,
# False conpositiones inscripserit. Illam enim inscriptionem ; quae
# False in fronte editionis principis legitur, a Ruellio ; non ab ipso
# False auctore profectam esse putaverim, qui quin potius de
# False conpositione medicamentorum, ut Aldus eumque secutus
# False Stephanus suo Marte emendaverunt ; scripturus fuerit ; equi-
# False dem non dubito ; sicuti Galenum libros decem tceql gvv-
# False &i<5Ecog cpccQ^ittKcov xcov KCittt xoitovQ et septem 7CSQL Gvv&e-
# False GEcog cpciQ[ittKCQv xcov %ccxtt yivr) inscripsisse constat. Qua
# False de causa mihi verisimilius esse visum est alteram inscrip-
# False tionem ; quae in editionis principis fol. I capitulo primo
# False praescripta est ; ipsius esse Scribonii.
# False His expositis restat, ut viris ; qui me in hac editione
# False adornanda et re et consilio multum adiuverunt ; gratias
# False agam publicas, Eduardo Woelfflin ; qui C. G. Ruehnii
# False programmata academica tria mecum communicavit ; quibus
# False Ottonis Sperlingii in Scribonium Largum animadversiones
# False aliquot publicatae sunt ; KaroloErnesto Georges, cuius
# False benignitati debeo editionis Rhodianae exemplar, quod quon-
# False dam C. A. Roettigeri fuit ; cuius in margine emendationes
# False nonnullas ab hoc viro adscriptas repperi, Iwano Mueller
# False praeceptori dilectissimo ; quem in plagulis corrigendis adiu-
# False torem habui diligentissimum.
# True Scribebam Augustae Vindelicorum
# False a. d. IV id. Iun. MDCCCLXXXVII.
# True Georgius Helmreich.
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
# True totius artis perceptione, qua homini permittitur, iudicavi-
# False mus ; quia ex hac omnia commoda nos consecuturos existi-
# False mabamus ; non medius fldius tam ducti pecuniae aut gloriae
# False cupiditate quam ipsius artis scientia. Magnum enim et
# False supra hominis naturam duximus posse aliquem tueri vel 5
# False reciperare suam et unius cuiusque bonam valetudinem.
# False Itaque ut ceteris partibus disciplinae, ita huic quoque,
# False quae per medicamenta virtutem suam exhibet, curiose
# False institimus, eo magis quod percipiebamus in dies ex usu
# True profectus eius ; quos interdum supra fidem atque opinionem 10
# False plurimorum exhibebamus. Sed quid ultra opus est pro-
# False bare necessarium usum esse medicamentorum, praecipue
# False tibi ; qui quia percepisti utilitatem eorum ; idcirco a me
# True conpositiones quasdam petisti? Ego autem memor humani-
# False tatis tuae candorisque animi tui ; quem omnibus quidem 15
# True hominibus plene ; mihi autem etiam peculiariter praestas ;
# False non solum quas desiderasti ; verum etiam si quas alias
# False expertas in praesenti habui ; in hunc librum contuli. Cupio
# False enim medius fidius ; qua possum ; tuae in me tam perse-
# False veranti benevolentiae respondere adiutus omni tempore a 20
# False te ; praecipue vero his diebus. Ut primum enim potuisti ;
# False non es passus cessare tuae erga me pietatis officium tra-
# False dendo scripta mea latina medicinalia deo nostro Caesari ;
# True quorum potestatem tibi feceram ; ut ipse prior legeres
# False simpliciterque indicares mihi ; quid sentires: plurimum 25
# False enim iudicio tuo tribuo. Tu porro candidissimo animo et
# False erga me benevolentissimo diligentiam meam sub tanti no-
# False minis editione non verbis ; sed re probasti periculumque
# False non minus tu iudicii quam ego stili propter me adisti,
# False quo tempore divinis manibus laudando consecrasti. Fateor 30
# True itaque libenter unicas me tibi gratias agere ; quod et prius
# True 1 qua Bhod.: qua L quae B. 4 scientiae Cornarius.
# False 5 vel M: et B. 6 reciperare L 1 : recuperare L*B. vali-
# False tudinem L 2 valet. L 1 . 14 petisti L: petiisti B. 16 ple-
# False nissime M. 20 benivolentiae LB. 21 istis pro his M.
# False 25 post sentires add. de his M. 27 benivolentissimo L. dili-
# False gentiam meam om. M. 29 tu Buecheler: tui BM.
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
# True — 29 —
# True dimidias et ita cetera diligenter trita admiscentur. Utrum-
# False que autem medicamentum stagneo reponendum est vaso.
# False LXVI. Ubi vero suppuratio faucium suspecta est
# False diutius permanente earum tumore et interdum febriculis
# False non sine horrore intercurrentibus oportebit gargarizare 5
# False quidem aqua mulsa crebrius furfuribus siligineis decocta
# False vel passo ad dimidias decocto bene caldo, uti ore et fau-
# False cibus diutius contineatur, vel ea aqua ; in qua ficus arida
# False pinguis erit decocta, perunguere autem fauces hoc medi-
# False camento 7 qua tactus sustinere poterit, pusillo pressius: 10
# False Mellis optimi heminarn ; resinae terebinthinae p. X II ; rosae
# False cyathos II. Resinam cum rosa in duplici vaso ; uti solent
# True unguentarii ; liquefacere oportet ; deinde admiscere ei mel
# False et coquere ; donec spissum fiat medicamentum. Hoc etiam
# False cum eruperit suppuratio ; uti oportet: expurgat enim et 15
# False explet idem.
# False LXVIL Ad anginam prodest sanguinis detractio ; cu-
# False curbitarum admissio ceteraque auxilia ; quibus medici effi-
# False cacius utuntur. Medicamenta autem simplicia quidem haec
# False faciunt: Laser Cyrenaicum, si poterit inveniri: sin minus, 20
# False Syriacum aqua dilutum ; crassius per pinnam faucibus ad-
# False hibitum; item euphorbium aqua dilutum.
# False LXVHI. Conpositorum autem medicamentorum haec
# False sunt apta: Fellis taurini ; salis ; aceti, mellis ; olei veteris
# False aequas partes in unum miscere oportet et cum opus fuerit, 25
# False pinna perfricare fauces diutius.
# False LXVIIIL Item bene facit: Git fricti p. X II, pyrethri
# False p. X I ; sagapeni victoriati pondus; melle miscentur haec
# False in unum trita.
# False LXX. Facit bene et hoc medicamentum: Fellis tau- 30
# False rini p. X II, elaterii, qui est sucus cucumeris silvatici ;
# False p. X I ; cachryos animati p. X I; tritum melle admixto
# False reponitur. Cum opus est ; dilutum aqua tepida sumitur et
# True 5 incurrentibus M. 10 qua L: quam B quantum Cor-
# False narius. 12 fortasse quo uti. 15 oportebit M. 17 et ante
# False sanguinis add. B, om. M. 18 admissio] admotio Bhod. 22
# False euforbium B. 27 fricti M: frictum B. 33 sumitur M:
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
# True - 86 -
# True moniaci guttae p. X XXIIII 7 terebinthinae p. X L ; olei
# False veteris sextarios quattuor. Oleo infervescit spuma argen-
# False tea trita curiose, deinde adicitur bitumen et ipsum con-
# False tusum et tritum. Ubi haec cerati mollis habent tempera-
# False 5 mentum, pix adicienda est ; deinde cera et propolis, postea
# False ammoniacum ; a quo aerugo; ultimum alumen aspergitur.
# False Oportet autem ubi tumor suspectus est ; lanam sucidam
# False ex vino sine oleo superponere.
# True CGX. Emplastrum nigrum Tryphonis ; basilicon ap-
# False 10 pellatur ; facit ad contusa et canis morsum et furunculos.
# False Idem rosa dilutum explet concava vnlnera: Picis Bruttiae
# False p. X XL ? resinae p. X XL ; galbani p. X II ; olei cyprei
# False pondo sescuncia. Cum oleo communi pix liquefit et coqui-
# False tur ; donec coeat; post hoc resina adicitur; deinde <(cum)>
# False 15 emplastri habet temperamentum ? deponitur caccabus et
# False tepente medicamento galbanum dilatatum ; ne uno loco
# False subsidat ; adicitur.
# True CCXI. Emplastrum nigrum, quod tetqckpccqiicckqv dici-
# False tur ; facit ad eadem. Recipit haec: Cerae ; picis, resinae
# False 20 frictae paria pondera ; adipis taurini dimidium; una omnia
# False coquuntur ; donec emplastrum fiat.
# False CCXII. Emplastrum Dionysi chirurgi facit ad medio-
# False cria vulnera et in teneris corporibus puerorum. Idem
# False iungit belle vulnera et sine tumore servat: Spumae ar-
# False 25 genteae p. X CXX ; olei sextarios duos. Haec super ignem
# False moventur ; donec cerati habeant temperaturam; post hoc
# False adicitur aluminis p. X XLV et decoquitur, usque dum
# False rufum medicamentum fiat. Post haec adicitur resinae
# False colophoniae p. X XLV ; cerae p. X XLV. Ubi emplastri
# False 30 omnia habuerint spissitudinem ; deponitur caccabus et
# True 9 Triphonis B. basilice B in indice. 13 pondo seseim-
# False cia ego: X p°. sescuncia B. pix scripsi: X p. IX B. liquefit
# False scripsi: liquefiet B. 14 cum addidi. 15 habet scripsi:
# False habens B. 18 Emplastrum nigrum Aristi chirurgi B in
# False indice et lemmate. tetrapharmacos B in indice. 28 medi-
# False camentam gJossema videtur.
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
# True — 95 -
# True etiam si cancer temptat; est autem lene: Auripigmenti,
# False quod Graeci aq<ssvi%ov dicunt, p. X VI ; aeris squamae
# False p. X III, elaterii p. X I ; chartae conbustae cineris p. X III.
# False Cum opus est ; coclearia tria rosae cyatho permiscentur,
# False inde linteola carpta continguntur atque ita ulceri super- 5
# False ponuntur. Hoc medicamentum cito et sine ullo morsu
# False expurgat sordidissima ulcera.
# False CCXJLXVIII. Omne purum ulcus et concavum replet
# False basilice rosa diluta ; ut superius dixi, proprie autem hoc
# False medicamentum: Medullae vitulinae p. X IIII ; adipis anse- 10
# False rini p. X II, butyri p. X II ; medullae cervinae p. X II,
# False cerae p. X IIII, terebinthinae p. X II, mellis pondo sescun-
# False cia, rosae pondo sescuncia. Resina cum rosa liquescit,
# False cui miscentur calenti mel et cera; cum cera praecalfacta
# False in ferventi aqua contunduntur atque ita superioribus 15
# False miscentur.
# False CCXXXVIIII. Omne ulcus luxurians et crescens carne
# False compescit chalcitis per se trita vel aeris flos ustus. Bene
# False autem et proprie hoc medicamentum facit, quo Meges
# False utebatur: Calcis vivae p. X II, turis p. X I, aeris squa- 20
# False mae p. X I.
# False CCXL. Tryphon chirurgus carnem eminentem hoc
# False medicamento compescebat: Aeris floris usti p. X VI, chal-
# False citis ustae p. X IIII, misys usti p. X IIII, aeris usti
# False p. X IIII. Hoc acre est et quasi cauterium crustam altam 25
# True facit; quamobrem cancer non patitur inpositum serpere,
# False omnem eruptionem sanguinis veluti cauterium sistit. Et
# False hoc autem et quae diximus imminuit; cicatricem quoque
# False ducit, si quis tincto extractoque specillo, quod ei quasi
# False pulvis adhaeserit, exiguo oras ulceris tetigerit. Sed pro- 30
# False prie cicatricem medicamenta haec ducunt:
# False CCXLI. Emplastrum efficax ad cicatricem ducendam:
# False Spumae argenteae p. X L, misy usti, chalcitis ustae, alu-
# True 1 et iam B. lene M : leve B. 3 cineris M : cinis B.
# False 9 superius] c. 210. proprie Bhod.: prope B. 12 mellis X
# False p. sesctincia, rosae X p. sescuncia B. 14 cum cera] an tum
# False cetera? 22 Triphon B. 24 mysis B. 33 mysii B.
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================
#
#
# =================

# %%
from xml.sax.saxutils import escape

def write_block(f, block, name=""):
    f.write(f"\t<{name.upper()}>\n")
    f.write("\t\t<FULL_TEXT>\n")
    for line in block:
        f.write(f"\t\t\t{escape(' '.join([w.text for w in line.words]))}\n")
    f.write("\t\t</FULL_TEXT>\n")
    for line in block:
        f.write(f"\t\t<LINE>{' '.join(['<WORD>'+escape(w.text)+'</WORD>' for w in line.words])}</LINE>\n")
    f.write(f"\t</{name.upper()}>\n")

with open("scribonius_largus.xml", "w") as f:
    f.write("<TEXT>\n")
    for page in pages:
        f.write(f"""<PAGE n="{page.id}" type="scan" uri="{escape(page.uri)}">
""")
        if page.nb_blocks >= 3:
            header, body, *notes = page.iter_blocks()
            write_block(f, header, name="header")
            write_block(f, body, name="body")
            for note in notes:
                write_block(f, note, name="note")
        else:
            write_block(f, page.lines, name="UNQUALIFIED")
        #print(list(page.iter_blocks()))
        f.write("""
</PAGE>
""")    
    f.write("</TEXT>\n")

# %%
new_xml = ET.parse("scribonius_largus_blocks.xml")

NewWord = namedtuple("NewWord", ["text", "page", "line"])

class NewLine:
    def __init__(self, w_elements, page_no, line_no):
        self.page_no = page_no
        self.line_no = line_no
        self.words = w_elements
        
        self._text = []
        self._num = None
        
    def line_and_text(self):
        if not self._text:
            if len(self.words) <= 1:
                self._num, self._text = None, self.words
            elif self.words[0].text.isnumeric():
                self._num, self._text = self.words[0].text, self.words[1:]
            elif self.words[-1].text.isnumeric():
                self._num, self._text = self.words[-1].text, self.words[:-1]
            else:
                self._num, self._text = None, self.words
        return self._num, self._text
        
    def __repr__(self):
        no, text = self.line_and_text()
        if no:
            return f'<lb n="{no}" />{" ".join([w.text for w in text])}'
        return " ".join([w.text for w in text])
    
    def get_and_pop_first(self):
        line, text = self.line_and_text()
        return text.pop(0)
    
    def last_word(self):
        if self._text:
            return self._text[-1]
        else:
            return None
      
#NewLine = namedtuple("NewLine", ["words", "page", "line"])

lines = []
all_pages = new_xml.xpath("//PAGE")
for page in all_pages:
    page_num = int(page.attrib["n"])
    if page_num < 116 and page_num >= 8:
        for line_no, line in enumerate(page.xpath("./BODY/LINE")):
            words = line.xpath(".//WORD")
            if not len(words):
                print(ET.tostring(line))
                raise Exception
            lines.append(NewLine(words, page_num, line_no))

print(len(lines))

last_p = None
last_l = None

import regex

NUMBER = regex.compile("[XVILCD]+")
GREEK_WORD = regex.compile("([a-z]+[A-Z]+[a-z]*|\w+\W+\w+)\W\s*")

def render_word(word):
    word = word.replace(")>", "❱").replace("<(", "❰")
    if GREEK_WORD.match(word):
        print(word)
        return f'<foreign xml:lang="grc">{escape(word)}</foreign>'
    return escape(word)
    
with open("scribonius_largus_tei.xml", "w") as f:
    for line, line_n1 in zip(lines, lines[1:]+[None]):
        # print(line.page_no, line.line_no)
        no, words = line.line_and_text()

        if last_p != line.page_no:
            f.write(f'\t<pb n="{line.page_no}" facs="https://archive.org/details/cuascriboniilarg00scri/page/n{line.page_no}/mode/1up"/>\n')
            last_p = line.page_no

        f.write(f'\t<lb n="{line.line_no+1}" />\n')

        if line_n1 is not None and \
           line.last_word() is not None and \
           line.last_word().text.endswith("-"):

            words[-1].text = words[-1].text[:-1] + line_n1.get_and_pop_first().text

        line = " "
        for word in words:
            line += render_word(word.text) + " "
        f.write("\t"+line+"\n")
# Out:
# 3144
# 7tdQ"r\
# 7tccQ<x6Kev<x>v,
# 6%ot(o^atLKovg
# tioXvvevqov,
# 7tEQi%Qi6t<x
# i-rjQocp&cd(ACav
# e?sent,
# l%iky\nxi%ovg
# anoTco(iccnKovg
# di%ta^vov
# xoloKvv&idct
# uq6svi%ov,
# nsqmlv^ivov,
# 6%oIotc£v8qiov,
# fiotuvYi,
# 6't-vTQicpvXkov
# T)pp<i£
# tpL^iv&iov
# ccql<jtoXo%icc
# 1%ks%uCxi%ov
# xctQ%ivcQ[icc
# aq<ssvi%ov
# oTtiG&orovov,
# pei*unguere.
